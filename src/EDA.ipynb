# %% [markdown]
# # EDA exploratorio para la compresion y la visualizacíon de los datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '../Airbnb_Data.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Primeras filas

# %%
df.shape
# Out:
# (53063, 29)

# %% [markdown]
# Informacion del dataset

# %%
#Observamos la informacion general del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53063 entries, 0 to 53062
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      53063 non-null  int64
#  1   log_price               53063 non-null  float64
#  2   property_type           53063 non-null  object
#  3   room_type               53063 non-null  object
#  4   amenities               53063 non-null  object
#  5   accommodates            53063 non-null  int64
#  6   bathrooms               52937 non-null  float64
#  7   bed_type                53063 non-null  object
#  8   cancellation_policy     53063 non-null  object
#  9   cleaning_fee            53063 non-null  bool
#  10  city                    53063 non-null  object
#  11  description             53063 non-null  object
#  12  first_review            41222 non-null  object
#  13  host_has_profile_pic    52925 non-null  object
# ...

# %% [markdown]
# Estadisticas

# %%
#Analizamos la presencia de valores nulos
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# id                            0
# log_price                     0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   126
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# description                   0
# first_review              11841
# host_has_profile_pic        138
# host_identity_verified      138
# host_response_rate        14992
# host_since                  138
# instant_bookable              0
# last_review               11816
# latitude                      0
# longitude                     0
# name                          0
# neighbourhood              4556
# number_of_reviews             0
# review_scores_rating      12507
# thumbnail_url                 0
# zipcode                     710
# bedrooms                     71
# beds                         95
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.hist(figsize=(10,10), bins=20)
plt.show()

# %%
for code in df['zipcode'].unique():
    subset_df = df[df['zipcode'] == code]
    unique_cities = subset_df['city'].unique()
    if len(unique_cities) != 1:
        print(code)
# Out:
# nan

# %%
df['zipcode'].describe()
# Out:
# count       52353
# unique        733
# top       11211.0
# freq         1013
# Name: zipcode, dtype: object
